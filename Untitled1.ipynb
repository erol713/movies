# %%
import numpy as np 
import pandas as pd

# %%
meta= pd.read_csv("movies_metadata.csv")
meta= meta[['id', 'title', 'budget', 'genres', 'release_date', 'revenue', 'vote_average', 'vote_count']]

meta= meta.rename(columns={'id':'movieId'})
meta.head()
# Out:
# /home/erol/jupyter/jupyter/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   movieId                        title    budget  \
# 0     862                    Toy Story  30000000
# 1    8844                      Jumanji  65000000
# 2   15602             Grumpier Old Men         0
# 3   31357            Waiting to Exhale  16000000
# 4   11862  Father of the Bride Part II         0
#
#                                               genres release_date  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...   1995-10-30
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   1995-12-15
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   1995-12-22
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   1995-12-22
# 4                     [{'id': 35, 'name': 'Comedy'}]   1995-02-10
#
# ...

# %%
meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 8 columns):
# movieId         45466 non-null object
# title           45460 non-null object
# budget          45466 non-null object
# genres          45466 non-null object
# release_date    45379 non-null object
# revenue         45460 non-null float64
# vote_average    45460 non-null float64
# vote_count      45460 non-null float64
# dtypes: float64(3), object(5)
# memory usage: 2.8+ MB

# %%
from ast import literal_eval
# Returns the list top l elements or entire list; whichever is more.
def get_list(x, l=5):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        #Check if more than l elements exist. If yes, return only first three. If no, return entire list.
        if len(names) > l:
            names = names[:l]
        return names

    #Return empty list in case of missing/malformed data
    return []

meta['genres'] = meta['genres'].apply(literal_eval)
meta['genres'] = meta['genres'].apply(get_list)

# %%
meta.head()
# Out:
#   movieId                        title    budget  \
# 0     862                    Toy Story  30000000
# 1    8844                      Jumanji  65000000
# 2   15602             Grumpier Old Men         0
# 3   31357            Waiting to Exhale  16000000
# 4   11862  Father of the Bride Part II         0
#
#                          genres release_date      revenue  vote_average  \
# 0   [Animation, Comedy, Family]   1995-10-30  373554033.0           7.7
# 1  [Adventure, Fantasy, Family]   1995-12-15  262797249.0           6.9
# 2             [Romance, Comedy]   1995-12-22          0.0           6.5
# 3      [Comedy, Drama, Romance]   1995-12-22   81452156.0           6.1
# 4                      [Comedy]   1995-02-10   76578911.0           5.7
#
#    vote_count
# 0      5415.0
# 1      2413.0
# 2        92.0
# 3        34.0
# 4       173.0

# %%
meta = meta[meta.vote_average != 0.0]

# %%
meta.vote_average.value_counts().head()
# Out:
# 6.0    2468
# 5.0    2001
# 7.0    1886
# 6.5    1722
# 6.3    1603
# Name: vote_average, dtype: int64

# %%
keys = pd.read_csv('keywords.csv')

# %%
keys.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
mym = pd.read_csv('movies.csv', index_col=0)

# %%
mym.head()
# Out:
#      Watched        Date     Day  Rating  \
# 0    with gf  2018-03-30  friday     4.0
# 32    Family  2018-05-07  monday     1.0
# 64   with gf  2018-06-10  sunday     4.0
# 96   with gf  2018-08-05  sunday     4.0
# 128  with gf  2018-09-23  sunday     3.5
#
#                                            Movie Title  year filmed  director  \
# 0    NestoDa jedesBilo staPa hun ako pojedesJednu k...           29  received
# 32   I popricatiRekla sam o cemuJa se svaki put ibr...           29  received
# 64   Ar ju apSta cemo kako cemoJa moram usisati sor...           29  received
# 96   Moram naci rijesenjeA da to rijesenje nijeKrse...           29  received
# 128  MozeSad me zanimaBejb odoh da jedem na brzinuO...           29  received
#
#         genre                                          key words
# 0    mot talk  ['moram', 'sada', 'hun', 'opet', 'ici', 'odoh'...
# 32   mot talk  ['moram', 'sada', 'hun', 'opet', 'ici', 'odoh'...
# ...

# %%
mym.Rating.value_counts()
# Out:
# 3.0    68
# 5.0    61
# 4.0    57
# 4.5    32
# 3.5    31
# 2.0    25
# 1.0     6
# Name: Rating, dtype: int64

# %%
fives.head()
# Out:
#     movieId                     title    budget          genres release_date  \
# 314     278  The Shawshank Redemption  25000000  [Drama, Crime]   1994-09-23
# 834     238             The Godfather   6000000  [Drama, Crime]   1972-03-14
#
#          revenue  vote_average  vote_count
# 314   28341469.0           8.5      8358.0
# 834  245066411.0           8.5      6024.0

# %%
fives = meta[(meta['vote_average'] >= 8.0) & (meta['vote_average'] < 9.0) & (meta['vote_count'] > 500) & (meta['budget'] !='0')]
myfives = fives.sample(n=61, random_state=1)

myfives = myfives.drop('movieId', axis=1)

# %%
fourfives = meta[(meta['vote_average'] >= 7.5) & (meta['vote_average'] < 8.0) & (meta['vote_count'] > 500) & (meta['budget'] !='0')]
myfourfives = fourfives.sample(n=32, random_state=1)

myfourfives = myfourfives.drop('movieId', axis=1)

# %%
fours = meta[(meta['vote_average'] >= 7.0) & (meta['vote_average'] < 7.5) & (meta['vote_count'] > 500) & (meta['budget'] !='0')]
myfours = fours.sample(n=57, random_state=1)

myfours = myfours.drop('movieId', axis=1)

# %%
threes = meta[(meta['vote_average'] >= 5.5) & (meta['vote_average'] < 6.0) & (meta['vote_count'] > 500) & (meta['budget'] !='0')]
mythrees = threes.sample(n=68, random_state=1)

mythrees = mythrees.drop('movieId', axis=1)

# %%
threesfives = meta[(meta['vote_average'] >= 6.5) & (meta['vote_average'] < 7.0) & (meta['vote_count'] > 500) & (meta['budget'] !='0')]
mythreesfives = threesfives.sample(n=31, random_state=1)

mythreesfives = mythreesfives.drop('movieId', axis=1)

# %%
twos = meta[(meta['vote_average'] >= 5.0) & (meta['vote_average'] < 5.5) & (meta['vote_count'] > 500) & (meta['budget'] !='0')]
mytwos = twos.sample(n=25, random_state=1)

mytwos = mytwos.drop('movieId', axis=1)

# %%
ones = meta[(meta['vote_average'] < 5.0) & (meta['vote_count'] > 500) & (meta['budget'] !='0')]
myones = ones.sample(n=6, random_state=1)

myones = myones.drop('movieId', axis=1)

# %%
myones
# Out:
#                                       title     budget               genres  \
# 20791                         Scary Movie 5   20000000             [Comedy]
# 18101                         Jack and Jill   79000000             [Comedy]
# 23110                The Legend of Hercules   70000000  [Action, Adventure]
# 7939                               Catwoman  100000000      [Action, Crime]
# 32891                           Knock Knock    2500000    [Drama, Thriller]
# 15132  The Human Centipede (First Sequence)    2011799             [Horror]
#
#       release_date      revenue  vote_average  vote_count
# 20791   2013-04-11   78378744.0           4.6       813.0
# 18101   2011-11-11  149673788.0           4.0       619.0
# 23110   2014-01-10   61279452.0           4.4       542.0
# 7939    2004-07-22   82102379.0           4.2       833.0
# 32891   2015-06-26    6341684.0           4.9       880.0
# 15132   2009-04-26          0.0           4.9       528.0

# %%
mytwos
# Out:
#                                         title     budget  \
# 39694                          47 Meters Down    5500000
# 24939                      Dumb and Dumber To   40000000
# 5646                               Ghost Ship   35000000
# 43238                               The Mummy  125000000
# 13006                               Max Payne   35000000
# 28763                             Poltergeist   35000000
# 17272                           Green Lantern  200000000
# 27478                    Fifty Shades of Grey   40000000
# 27477                               Mortdecai   60000000
# 16737                             Drive Angry   50000000
# 39920                  Mechanic: Resurrection   40000000
# 14258                         Couples Retreat   70000000
# 11864  Fantastic 4: Rise of the Silver Surfer  130000000
# 39149                            Ghostbusters  144000000
# 20536                   G.I. Joe: Retaliation  130000000
# ...

# %%
mym.drop(['Movie Title', 'year filmed', 'director', 'genre', 'key words'], axis=1, inplace=True)
# Out:
#       Watched        Date        Day  Rating
# 0     with gf  2018-03-30     friday     4.0
# 32     Family  2018-05-07     monday     1.0
# 64    with gf  2018-06-10     sunday     4.0
# 96    with gf  2018-08-05     sunday     4.0
# 128   with gf  2018-09-23     sunday     3.5
# 160   with gf  2018-11-11     sunday     3.0
# 192    Family  2018-12-25    tuesday     3.0
# 224   with gf  2019-02-28   thursday     4.5
# 256     Alone  2018-03-30     friday     5.0
# 288     Alone  2018-04-30     monday     4.0
# 320     Alone  2018-06-02   saturday     3.5
# 352    Family  2018-08-04   saturday     3.0
# 384     Alone  2018-09-18    tuesday     2.0
# 416     Alone  2018-11-05     monday     4.5
# 448     Alone  2018-12-28     friday     4.0
# 480     Alone  2019-03-02   saturday     5.0
# 512    Family  2019-04-20   saturday     3.0
# 544   with gf  2018-04-10    tuesday     2.0
# 576   with gf  2018-10-27   saturday     4.0
# 608     Alone  2018-05-02  wednesday     4.5
# ...

# %%
fives = mym[mym['Rating'] == 5]
myfives = myfives.set_index(fives.index.values)
fives = pd.concat([fives, myfives], axis=1,join='inner')

# %%
fourfives = mym[mym['Rating'] == 4.5]
myfourfives = myfourfives.set_index(fourfives.index.values)
fourfives = pd.concat([fourfives, myfourfives], axis=1,join='inner')

# %%
fours = mym[mym['Rating'] == 4.0]
myfours = myfours.set_index(fours.index.values)
fours = pd.concat([fours, myfours], axis=1,join='inner')

# %%
threfives = mym[mym['Rating'] == 3.5]
mythreesfives = mythreesfives.set_index(threfives.index.values)
threfives = pd.concat([threfives, mythreesfives], axis=1,join='inner')

# %%
threes = mym[mym['Rating'] == 3.0]
mythrees = mythrees.set_index(threes.index.values)
threes = pd.concat([threes, mythrees], axis=1,join='inner')

# %%
twos = mym[mym['Rating'] == 2.0]
mytwos = mytwos.set_index(twos.index.values)
twos = pd.concat([twos, mytwos], axis=1,join='inner')

# %%
ones = mym[mym['Rating'] == 1.0]
myones = myones.set_index(ones.index.values)
ones = pd.concat([ones, myones], axis=1,join='inner')

# %%
mym = pd.concat([ones, twos, threes, threesfives, fours, fourfives, fives], sort=False)

# %%
mym.drop('movieId', axis=1, inplace=True)

# %%
#mym.to_csv('myWatchedMovies.csv')
