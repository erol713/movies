# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
df = pd.read_csv('myWatchedMovies2.csv', index_col = 0)

# %%
data = pd.read_csv('movies_metadata.csv')
# Out:
# /home/erol/jupyter/jupyter/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 249 entries, 32 to 8896
# Data columns (total 12 columns):
# Watched         249 non-null object
# Date            249 non-null object
# Day             249 non-null object
# Rating          249 non-null float64
# movieId         249 non-null int64
# title           249 non-null object
# budget          249 non-null int64
# genres          249 non-null object
# release_date    249 non-null object
# revenue         249 non-null int64
# vote_average    249 non-null float64
# vote_count      249 non-null int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 25.3+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
# adult                    45466 non-null object
# belongs_to_collection    4494 non-null object
# budget                   45466 non-null object
# genres                   45466 non-null object
# homepage                 7782 non-null object
# id                       45466 non-null object
# imdb_id                  45449 non-null object
# original_language        45455 non-null object
# original_title           45466 non-null object
# overview                 44512 non-null object
# popularity               45461 non-null object
# poster_path              45080 non-null object
# production_companies     45463 non-null object
# production_countries     45463 non-null object
# release_date             45379 non-null object
# revenue                  45460 non-null float64
# runtime                  45203 non-null float64
# spoken_languages         45460 non-null object
# ...

# %%
df.head()
# Out:
#      Watched        Date       Day  Rating  movieId                   title  \
# 32    Family  2018-05-07    monday     1.0     4258           Scary Movie 5
# 1632  Family  2018-05-14    monday     1.0    71880           Jack and Jill
# 3232  Family  2018-07-07  saturday     1.0   188207  The Legend of Hercules
# 4832  Family  2018-12-25   tuesday     1.0      314                Catwoman
# 6432  Family  2018-04-16    monday     1.0   263472             Knock Knock
#
#          budget                   genres release_date    revenue  \
# 32     20000000               ['Comedy']   2013-04-11   78378744
# 1632   79000000               ['Comedy']   2011-11-11  149673788
# 3232   70000000  ['Action', 'Adventure']   2014-01-10   61279452
# 4832  100000000      ['Action', 'Crime']   2004-07-22   82102379
# 6432    2500000    ['Drama', 'Thriller']   2015-06-26    6341684
#
#       vote_average  vote_count
# 32             4.6         813
# 1632           4.0         619
# ...

# %%
df.Watched.value_counts()
# Out:
# Alone      95
# Family     79
# with gf    75
# Name: Watched, dtype: int64

# %%
df.Day.value_counts()
# Out:
# saturday     56
# sunday       50
# friday       38
# tuesday      36
# monday       24
# thursday     23
# wednesday    22
# Name: Day, dtype: int64

# %%
df.Rating.value_counts()
# Out:
# 3.0    68
# 5.0    61
# 4.0    57
# 4.5    32
# 2.0    25
# 1.0     6
# Name: Rating, dtype: int64

# %%
df.genres.value_counts().head()
# Out:
# ['Drama']                         14
# ['Comedy']                        13
# ['Drama', 'Crime']                 6
# ['Comedy', 'Romance']              5
# ['Comedy', 'Drama', 'Romance']     4
# Name: genres, dtype: int64

# %%
df[df['Watched'] == 'with gf']['genres'].value_counts().head()
# Out:
# ['Comedy']                                             5
# ['Horror', 'Thriller']                                 4
# ['Horror', 'Mystery', 'Thriller']                      3
# ['Horror']                                             3
# ['Horror', 'Action', 'Thriller', 'Science Fiction']    2
# Name: genres, dtype: int64

# %%
df[df['Watched'] == 'Family']['genres'].value_counts().head()
# Out:
# ['Comedy']                            6
# ['Comedy', 'Romance']                 5
# ['Comedy', 'Family']                  2
# ['Action', 'Adventure']               2
# ['Adventure', 'Fantasy', 'Family']    2
# Name: genres, dtype: int64

# %%
df[df['Watched'] == 'Alone']['genres'].value_counts().head()
# Out:
# ['Drama']                             14
# ['Drama', 'Crime']                     6
# ['Drama', 'War']                       3
# ['Crime', 'Drama', 'Thriller']         3
# ['Adventure', 'Fantasy', 'Action']     3
# Name: genres, dtype: int64

# %%
df[(df['Day'] == 'sunday') | (df['Day'] == 'saturday')]['genres'].value_counts().head()
# Out:
# ['Drama']                            6
# ['Comedy']                           5
# ['Horror', 'Thriller']               4
# ['Horror']                           3
# ['Horror', 'Mystery', 'Thriller']    3
# Name: genres, dtype: int64

# %%
df[(df['Day'] != 'sunday') | (df['Day'] != 'saturday')]['genres'].value_counts().head()
# Out:
# ['Drama']                         14
# ['Comedy']                        13
# ['Drama', 'Crime']                 6
# ['Comedy', 'Romance']              5
# ['Comedy', 'Drama', 'Romance']     4
# Name: genres, dtype: int64

# %%
df.head()
# Out:
#      Watched        Date       Day  Rating  movieId                   title  \
# 32    Family  2018-05-07    monday     1.0     4258           Scary Movie 5
# 1632  Family  2018-05-14    monday     1.0    71880           Jack and Jill
# 3232  Family  2018-07-07  saturday     1.0   188207  The Legend of Hercules
# 4832  Family  2018-12-25   tuesday     1.0      314                Catwoman
# 6432  Family  2018-04-16    monday     1.0   263472             Knock Knock
#
#          budget             genres release_date    revenue  vote_average  \
# 32     20000000             Comedy   2013-04-11   78378744           4.6
# 1632   79000000             Comedy   2011-11-11  149673788           4.0
# 3232   70000000  Action, Adventure   2014-01-10   61279452           4.4
# 4832  100000000      Action, Crime   2004-07-22   82102379           4.2
# 6432    2500000    Drama, Thriller   2015-06-26    6341684           4.9
#
#       vote_count
# 32           813
# 1632         619
# ...

# %%
df.genres.value_counts()
# Out:
# Drama                                                    14
# Comedy                                                   13
# Drama, Crime                                              6
# Comedy, Romance                                           5
# Action, Crime, Thriller                                   4
# Comedy, Drama                                             4
# Horror, Thriller                                          4
# Comedy, Drama, Romance                                    4
# Adventure, Fantasy, Action                                3
# Horror                                                    3
# Drama, Thriller                                           3
# Adventure, Action, Thriller                               3
# Crime, Drama, Thriller                                    3
# Drama, War                                                3
# Horror, Mystery, Thriller                                 3
# Action, Adventure, Science Fiction, Thriller              2
# ...

# %%
df['Watched'] = df["Watched"].astype('category')

# %%
df['Day'] = df["Day"].astype('category')

# %%
df2 = df

# %%
z = []
for i in df.genres:
    x = i.split(',')
    for i in x:        
        if i not in z:
            z.append(i)
        else:
            continue

# %%
z
# Out:
# ['Comedy',
#  'Action',
#  ' Adventure',
#  ' Crime',
#  'Drama',
#  ' Thriller',
#  'Horror',
#  ' Horror',
#  ' Mystery',
#  'Thriller',
#  ' Action',
#  'Adventure',
#  ' Science Fiction',
#  ' Romance',
#  'Fantasy',
#  ' Fantasy',
#  ' Comedy',
#  ' Drama',
#  'Crime',
#  ' Family',
#  'Animation',
#  ' Western',
#  'Romance',
#  'Science Fiction',
#  ' Music',
#  ' War',
#  'War',
#  ' History',
#  'Family',
#  ' Animation',
#  'Mystery',
#  'Western',
#  'Music',
#  'History']

# %%
df2  = pd.DataFrame(None , columns=z)

# %%
df3 = pd.concat([df, df2], axis=1)

# %%
df3
# Out:
#       Watched        Date        Day  Rating  movieId  \
# 32     Family  2018-05-07     monday     1.0     4258
# 1632   Family  2018-05-14     monday     1.0    71880
# 3232   Family  2018-07-07   saturday     1.0   188207
# 4832   Family  2018-12-25    tuesday     1.0      314
# 6432   Family  2018-04-16     monday     1.0   263472
# 8032   Family  2018-06-20  wednesday     1.0    37169
# 384     Alone  2018-09-18    tuesday     2.0   403119
# 544   with gf  2018-04-10    tuesday     2.0   100042
# 640     Alone  2018-09-16     sunday     2.0     9645
# 768     Alone  2018-04-30     monday     2.0   282035
# 1504  with gf  2018-04-17    tuesday     2.0    13051
# 1696  with gf  2018-05-28     monday     2.0   243688
# 1888  with gf  2018-08-03     friday     2.0    44912
# 2304  with gf  2018-11-19     monday     2.0   216015
# 2368  with gf  2018-12-08   saturday     2.0   210860
# 2656  with gf  2019-02-26    tuesday     2.0    47327
# ...

# %%
df3['genres'].str.contains('Action')
df3.loc[df3['genres'].str.contains('Horror'), 'Day'] = "saturday"
# Out:
# 32      False
# 1632    False
# 3232     True
# 4832     True
# 6432    False
# 8032    False
# 384     False
# 544     False
# 640     False
# 768      True
# 1504     True
# 1696    False
# 1888     True
# 2304    False
# 2368    False
# 2656     True
# 3360     True
# 4128    False
# 4384     True
# 4896     True
# 5088     True
# 5344     True
# 5440    False
# 5760     True
# 6336     True
# 7168    False
# 7264     True
# 7296    False
# 7680    False
# 7840    False
#         ...
# 4864    False
# 4960    False
# 5184    False
# 5248    False
# 5280    False
# 5408    False
# 5536    False
# 5824    False
# 5856    False
# 6048     True
# 6080    False
# 6304    False
# 6528    False
# 6624    False
# 6720    False
# 6976    False
# 7200    False
# 7360    False
# 7424    False
# 7648    False
# 7744    False
# 8096    False
# 8160    False
# 8256     True
# 8320    False
# 8416     True
# 8544    False
# 8640    False
# 8768    False
# 8896    False
# ...

# %%
for i in df3.genres:
    x = i.split(',')
    for i in x:        
        if i in
